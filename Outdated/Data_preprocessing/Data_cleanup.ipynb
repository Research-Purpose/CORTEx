# %%
import pandas as pd

file_name = "Filtered_Matching_IDs.csv"
df = pd.read_csv(f'/home/wfd/Desktop/York/notebooks/Outdated/Data_preprocessing/filtered_matching_ids.csv')

print(df.columns)
# Out:
# Index(['Post Link', 'Title', 'CreationDate', 'Score', 'ViewCount',
#        'AnswerCount', 'CommentCount', 'FavoriteCount', 'Tags', 'Body',
#        'ClosedDate', 'CodeText', 'ImageURLs'],
#       dtype='object')

# %%
# Only keep the columns we need
needed_columns = ["Post Link", "Title", "Body", "ImageURLs"]
df = df[needed_columns]

# Rename columns
df = df.rename(columns={"Post Link": "Id"})

# %%
import re

def extract_image_url(img_list):
    if pd.isna(img_list):
        return []
    img_list = img_list.replace("[", "").replace("]", "").replace("'", "").split(',')
    img_list = [re.search(r'(https?://\S+)', img).group(0) for img in img_list]
    return img_list


# Remove \n from the body
df['Body'] = df['Body'].apply(lambda x: x.replace('\n', ' '))
df['ImageURLs'] = df['ImageURLs'].apply(extract_image_url)

# %%
print(df.head(5))
# Out:
#          Id                                              Title  \
# 0  78689138       Hosting A native PHP MySQL Project on vercel
# 1  78678692  Reading UTF-8 texts in PowerPoint via VBA, for...
# 2  78674751  Typescript interface disjunction gives incorre...
# 3  78673647  Http-only cookie in response header from backe...
# 4  78672889  Qt Creator design tab is greyed out in QML pro...
#
#                                                 Body  \
# 0  I have tried many things and even tried moving...
# 1  I want to read all text in a PowerPoint file u...
# 2  I have this function export async function get...
# 3  I have a fullstack app made up of a React fron...
# 4  I don't know if this is the expected behavior....
#
#                                            ImageURLs
# 0  [https://i.sstatic.net/UmhZ9zHE.png, https://i...
# 1               [https://i.sstatic.net/9nF6vUFK.png]
# 2               [https://i.sstatic.net/9QE26tpK.png]
# 3  [https://i.sstatic.net/lXkm8i9F.png, https://i...
# 4               [https://i.sstatic.net/oJO0UUzA.png]

# %%
# Dump the data to a new csv
df.to_csv(f'../../data_stackoverflow/{file_name}_CleanedUp.csv', index=False)

# %%
# Download the images
import requests
import os

def download_image(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, 'wb') as f:
            f.write(response.content)
            return True
    else:
        print(f'Failed to download {url}, status code {response.status_code}')
    return False

# Create a directory to store the images
os.makedirs('../images', exist_ok=True)

amount = len(df);
# Take a random sample of images
df = df.sample(amount)
count = 0

for index, row in df.iterrows():
    if (count == amount):
        break
    image_url = row['ImageURLs']
    for url in image_url:
        if url:
            cleaned_url = re.split("\.\w+", url.split('/')[-1])[0]
            if url.endswith('.gif'):
                print(f'{url} is a gif, skipping')
                continue
            filename = f'../images/{row["Id"]}_{cleaned_url}.png'
            # If the image exists, skip
            if os.path.exists(filename):
                print(f'{filename} already exists, skipping')
                continue
            print(f'Downloading {url} to {filename}')
            if download_image(url, filename):
                print(f'Downloaded {url} to {filename}')
                count += 1
            else:
                print(f'Failed to download {url}')
# Out:
# Downloading https://i.sstatic.net/Okjpu.png to ../images/76803209_Okjpu.png
# Downloaded https://i.sstatic.net/Okjpu.png to ../images/76803209_Okjpu.png
# ../images/78673647_lXkm8i9F.png already exists, skipping
# ../images/78673647_lGcu2ov9.png already exists, skipping
# ../images/77424574_okivq.png already exists, skipping
# Downloading https://i.sstatic.net/mUmrx.png to ../images/77243382_mUmrx.png
# <>:29: SyntaxWarning: invalid escape sequence '\.'
# <>:29: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_164590/363390476.py:29: SyntaxWarning: invalid escape sequence '\.'
#   cleaned_url = re.split("\.\w+", url.split('/')[-1])[0]
# Downloaded https://i.sstatic.net/mUmrx.png to ../images/77243382_mUmrx.png
# ../images/78261167_TQjP4.png already exists, skipping
# ../images/76866681_cdiLJ.png already exists, skipping
# ../images/78062372_BgpwP.png already exists, skipping
# ../images/78062372_47Kea.png already exists, skipping
# Downloading https://i.sstatic.net/obXa0.png to ../images/78313521_obXa0.png
# Downloaded https://i.sstatic.net/obXa0.png to ../images/78313521_obXa0.png
# ../images/78072195_PCaW8.png already exists, skipping
# Downloading https://i.sstatic.net/h73CO.jpg to ../images/76989815_h73CO.png
# Downloaded https://i.sstatic.net/h73CO.jpg to ../images/76989815_h73CO.png
# Downloading https://i.sstatic.net/PjBIt.jpg to ../images/76989815_PjBIt.png
# Downloaded https://i.sstatic.net/PjBIt.jpg to ../images/76989815_PjBIt.png
# Downloading https://i.sstatic.net/b8udQ.jpg to ../images/76989815_b8udQ.png
# Downloaded https://i.sstatic.net/b8udQ.jpg to ../images/76989815_b8udQ.png
# ../images/78340160_ZPBKR.png already exists, skipping
# ../images/77331424_GnS3U.png already exists, skipping
# Downloading https://i.sstatic.net/WAacj.png to ../images/78256921_WAacj.png
# Downloaded https://i.sstatic.net/WAacj.png to ../images/78256921_WAacj.png
# ../images/77738792_KkznL.png already exists, skipping
# ../images/77738792_QdeyS.png already exists, skipping
# ../images/77738792_I0a05.png already exists, skipping
# ../images/77618187_BJoFd.png already exists, skipping
# ../images/77618187_cLpMT.png already exists, skipping
# ../images/77552567_9nzuN.png already exists, skipping
# Downloading https://i.sstatic.net/0eUzz.png to ../images/77222558_0eUzz.png
# Downloaded https://i.sstatic.net/0eUzz.png to ../images/77222558_0eUzz.png
# ../images/77222558_F9xjp.png already exists, skipping
# Downloading https://i.sstatic.net/1caqh.png to ../images/77222558_1caqh.png
# Downloaded https://i.sstatic.net/1caqh.png to ../images/77222558_1caqh.png
# Downloading https://i.sstatic.net/ndPUM.png to ../images/77735741_ndPUM.png
# Downloaded https://i.sstatic.net/ndPUM.png to ../images/77735741_ndPUM.png
# Downloading https://i.sstatic.net/VeMVX.png to ../images/77735741_VeMVX.png
# Downloaded https://i.sstatic.net/VeMVX.png to ../images/77735741_VeMVX.png
# ../images/77735741_5G7BP.png already exists, skipping
# ../images/77400888_6iRee.png already exists, skipping
# ../images/76847282_H9tU8.png already exists, skipping
# ../images/76847282_Wi8Xn.png already exists, skipping
# ../images/76847282_mfkrG.png already exists, skipping
# ../images/76847282_obwVI.png already exists, skipping
# Downloading https://i.sstatic.net/CAkmf.png to ../images/78157621_CAkmf.png
# Downloaded https://i.sstatic.net/CAkmf.png to ../images/78157621_CAkmf.png
# Downloading https://i.sstatic.net/oTpq47fA.png to ../images/78420437_oTpq47fA.png
# Downloaded https://i.sstatic.net/oTpq47fA.png to ../images/78420437_oTpq47fA.png
# ../images/77903071_1cLph.png already exists, skipping
# Downloading https://i.sstatic.net/wfAHT.png to ../images/77122751_wfAHT.png
# Downloaded https://i.sstatic.net/wfAHT.png to ../images/77122751_wfAHT.png
# ../images/77122751_bV6Sm.png already exists, skipping
# ../images/77122751_kCZJQ.png already exists, skipping
# ../images/76866457_vlzrZ.png already exists, skipping
# ../images/76809354_COnbg.png already exists, skipping
# ../images/76809354_XMooF.png already exists, skipping
# ../images/78654946_65ZES0TB.png already exists, skipping
# ../images/77459136_AgPq0.png already exists, skipping
# ../images/77459136_8alCx.png already exists, skipping
# ../images/78362757_rCp0x.png already exists, skipping
# Downloading https://i.sstatic.net/dkTpw.png to ../images/78330592_dkTpw.png
# Downloaded https://i.sstatic.net/dkTpw.png to ../images/78330592_dkTpw.png
# ../images/78330592_VolkM.png already exists, skipping
# Downloading https://i.sstatic.net/3Gk4h3Hl.png to ../images/78460307_3Gk4h3Hl.png
# Downloaded https://i.sstatic.net/3Gk4h3Hl.png to ../images/78460307_3Gk4h3Hl.png
# Downloading https://i.sstatic.net/yr5xNL0w.jpg to ../images/78460307_yr5xNL0w.png
# Downloaded https://i.sstatic.net/yr5xNL0w.jpg to ../images/78460307_yr5xNL0w.png
# Downloading https://i.sstatic.net/tKGKX.png to ../images/77117859_tKGKX.png
# Downloaded https://i.sstatic.net/tKGKX.png to ../images/77117859_tKGKX.png
# Downloading https://i.sstatic.net/nOQQN.png to ../images/77262559_nOQQN.png
# Downloaded https://i.sstatic.net/nOQQN.png to ../images/77262559_nOQQN.png
# Downloading https://i.sstatic.net/HGbMY.png to ../images/77262559_HGbMY.png
# Downloaded https://i.sstatic.net/HGbMY.png to ../images/77262559_HGbMY.png
# ../images/77566768_BvugG.png already exists, skipping
# ../images/77566768_qcYgQ.png already exists, skipping
# Downloading https://i.sstatic.net/8x8MY.png to ../images/78046015_8x8MY.png
# Downloaded https://i.sstatic.net/8x8MY.png to ../images/78046015_8x8MY.png
# ../images/77070916_tuwj6.png already exists, skipping
# ../images/77193193_TZJ1b.png already exists, skipping
# Downloading https://i.sstatic.net/jKZu6.png to ../images/77276216_jKZu6.png
# Downloaded https://i.sstatic.net/jKZu6.png to ../images/77276216_jKZu6.png
# ../images/77128524_LHt8d.png already exists, skipping
# Downloading https://i.sstatic.net/8MwbdIhT.png to ../images/78599299_8MwbdIhT.png
# Downloaded https://i.sstatic.net/8MwbdIhT.png to ../images/78599299_8MwbdIhT.png
# Downloading https://i.sstatic.net/A4wRx.png to ../images/78235594_A4wRx.png
# Downloaded https://i.sstatic.net/A4wRx.png to ../images/78235594_A4wRx.png
# Downloading https://i.sstatic.net/OPcmz.png to ../images/78235594_OPcmz.png
# Downloaded https://i.sstatic.net/OPcmz.png to ../images/78235594_OPcmz.png
# Downloading https://i.sstatic.net/jg6Rp.png to ../images/78312777_jg6Rp.png
# Downloaded https://i.sstatic.net/jg6Rp.png to ../images/78312777_jg6Rp.png
# ../images/78343164_8MOzc.png already exists, skipping
# ../images/78614041_EDDcBvjZ.png already exists, skipping
# ../images/78614041_jEpqWVFd.png already exists, skipping
# Downloading https://i.sstatic.net/V69D3.png to ../images/78069396_V69D3.png
# Downloaded https://i.sstatic.net/V69D3.png to ../images/78069396_V69D3.png
# ../images/77774528_mcYHW.png already exists, skipping
# Downloading https://i.sstatic.net/PcMOM.png to ../images/77774528_PcMOM.png
# Downloaded https://i.sstatic.net/PcMOM.png to ../images/77774528_PcMOM.png
# ../images/77790983_BrnqG.png already exists, skipping
# ../images/77491685_WqCRV.png already exists, skipping
# ../images/77491685_JptiM.png already exists, skipping
# Downloading https://i.sstatic.net/lETHjU9F.jpg to ../images/78540221_lETHjU9F.png
# Downloaded https://i.sstatic.net/lETHjU9F.jpg to ../images/78540221_lETHjU9F.png
# ../images/77437468_ZfiwV.png already exists, skipping
# ../images/77683304_l0FXf.png already exists, skipping
# ../images/76927339_2WwaK.png already exists, skipping
# ../images/77977640_0193a.png already exists, skipping
# ../images/77977640_JhCNx.png already exists, skipping
# ../images/76811541_VFSml.png already exists, skipping
# ../images/77657275_Df86v.png already exists, skipping
# ../images/77657275_Sguod.png already exists, skipping
# ../images/78555378_BHGIqWiz.png already exists, skipping
# ../images/77392511_XnA10.png already exists, skipping
# ../images/78527028_oTJCGQnA.png already exists, skipping
# ../images/76900493_XfY2p.png already exists, skipping
# ../images/76900493_6waUu.png already exists, skipping
# ../images/76830172_a5Ije.png already exists, skipping
# ../images/76830172_JrBGd.png already exists, skipping
# ../images/76830172_7wEwO.png already exists, skipping
# ../images/78324652_f8O8D.png already exists, skipping
# ../images/78324652_WF2Ky.png already exists, skipping
# ../images/78536020_gYdWRbgI.png already exists, skipping
# Downloading https://i.sstatic.net/Ocgk1.png to ../images/76865717_Ocgk1.png
# Downloaded https://i.sstatic.net/Ocgk1.png to ../images/76865717_Ocgk1.png
# ../images/76865717_Kf5su.png already exists, skipping
# Downloading https://i.sstatic.net/Xr3zP.png to ../images/76865717_Xr3zP.png
# Downloaded https://i.sstatic.net/Xr3zP.png to ../images/76865717_Xr3zP.png
# Downloading https://i.sstatic.net/Oef8d.png to ../images/76865717_Oef8d.png
# Downloaded https://i.sstatic.net/Oef8d.png to ../images/76865717_Oef8d.png
# Downloading https://i.sstatic.net/jIUvj.png to ../images/76865717_jIUvj.png
# Downloaded https://i.sstatic.net/jIUvj.png to ../images/76865717_jIUvj.png
# ../images/77651170_XVxoA.png already exists, skipping
# ../images/78067794_myiFb.png already exists, skipping
# ../images/78067794_BKUyf.png already exists, skipping
# ../images/78067794_6vhK9.png already exists, skipping
# ../images/77886918_t6XN9.png already exists, skipping
# ../images/77527966_0JUNv.png already exists, skipping
# ../images/76842310_11lMV.png already exists, skipping
# ../images/77133944_imWHq.png already exists, skipping
# ../images/77133944_41R9D.png already exists, skipping
# ../images/78502935_cw7wvlZg.png already exists, skipping
# ../images/78502935_8MKgX6cT.png already exists, skipping
# Downloading https://i.sstatic.net/EuFYz.png to ../images/77377416_EuFYz.png
# Downloaded https://i.sstatic.net/EuFYz.png to ../images/77377416_EuFYz.png
# Downloading https://i.sstatic.net/qa2S6.png to ../images/78101959_qa2S6.png
# Downloaded https://i.sstatic.net/qa2S6.png to ../images/78101959_qa2S6.png
# Downloading https://i.sstatic.net/DxzjK.png to ../images/78101959_DxzjK.png
# Downloaded https://i.sstatic.net/DxzjK.png to ../images/78101959_DxzjK.png
# Downloading https://i.sstatic.net/kHO7Z.png to ../images/78026743_kHO7Z.png
# Downloaded https://i.sstatic.net/kHO7Z.png to ../images/78026743_kHO7Z.png
# ../images/78055212_USrhd.png already exists, skipping
# Downloading https://i.sstatic.net/YsFVO.png to ../images/78121400_YsFVO.png
# Downloaded https://i.sstatic.net/YsFVO.png to ../images/78121400_YsFVO.png
# Downloading https://i.sstatic.net/1icrX.png to ../images/77441967_1icrX.png
# Downloaded https://i.sstatic.net/1icrX.png to ../images/77441967_1icrX.png
# ../images/78002687_L6nP0.png already exists, skipping
# ../images/78342087_gMZKf.png already exists, skipping
# ../images/78342087_8Vn5W.png already exists, skipping
# Downloading https://i.sstatic.net/Pqwj0.png to ../images/77580157_Pqwj0.png
# Downloaded https://i.sstatic.net/Pqwj0.png to ../images/77580157_Pqwj0.png
# Downloading https://i.sstatic.net/0HisM.png to ../images/77580157_0HisM.png
# Downloaded https://i.sstatic.net/0HisM.png to ../images/77580157_0HisM.png
# ../images/78164857_jJcOj.png already exists, skipping
# ../images/78096655_A9rDF.png already exists, skipping
# ../images/78096655_u5x0c.png already exists, skipping
# Downloading https://i.sstatic.net/RzkGq.png to ../images/77054577_RzkGq.png
# Downloaded https://i.sstatic.net/RzkGq.png to ../images/77054577_RzkGq.png
# Downloading https://i.sstatic.net/BOtILMuz.png to ../images/78434652_BOtILMuz.png
# Downloaded https://i.sstatic.net/BOtILMuz.png to ../images/78434652_BOtILMuz.png
# Downloading https://i.sstatic.net/fzJJ3rx6.png to ../images/78446405_fzJJ3rx6.png
# Downloaded https://i.sstatic.net/fzJJ3rx6.png to ../images/78446405_fzJJ3rx6.png
# ../images/78135491_NyMZN.png already exists, skipping
# ../images/78603472_AVa96p8J.png already exists, skipping
# ../images/77675903_bhLMb.png already exists, skipping
# ../images/77920092_0nrYi.png already exists, skipping
# ../images/77920092_0Ys9P.png already exists, skipping
# ../images/78523096_9PkMGdKN.png already exists, skipping
# ../images/77507066_YZlB2.png already exists, skipping
# ../images/78639185_82yBrQBT.png already exists, skipping
# ../images/78639185_DPCmoj4E.png already exists, skipping
# ../images/77938559_yfILl.png already exists, skipping
# ../images/77938559_bU5A0.png already exists, skipping
# ../images/77938559_m1cZ3.png already exists, skipping
# Downloading https://i.sstatic.net/c9MQc.png to ../images/77979375_c9MQc.png
# Downloaded https://i.sstatic.net/c9MQc.png to ../images/77979375_c9MQc.png
# ../images/78595553_F32ha8Vo.png already exists, skipping
# Downloading https://i.sstatic.net/uFOwE.png to ../images/77152003_uFOwE.png
# Downloaded https://i.sstatic.net/uFOwE.png to ../images/77152003_uFOwE.png
# Downloading https://i.sstatic.net/ogKer.png to ../images/77152003_ogKer.png
# Downloaded https://i.sstatic.net/ogKer.png to ../images/77152003_ogKer.png
# ../images/77300476_4WJ1Y.png already exists, skipping
# ../images/78257814_QSs7O.png already exists, skipping
# Downloading https://i.sstatic.net/KbeU3.png to ../images/77440152_KbeU3.png
# Downloaded https://i.sstatic.net/KbeU3.png to ../images/77440152_KbeU3.png
# Downloading https://i.sstatic.net/Gjvzt.png to ../images/77440152_Gjvzt.png
# Downloaded https://i.sstatic.net/Gjvzt.png to ../images/77440152_Gjvzt.png
# ../images/78091549_Ya1Ct.png already exists, skipping
# ../images/77816823_Qtyuz.png already exists, skipping
# ../images/76957389_e2ocU.png already exists, skipping
# ../images/76957389_Wja6Y.png already exists, skipping
# ../images/78062995_pOL5S.png already exists, skipping
# ../images/78062995_eG46q.png already exists, skipping
# Downloading https://i.sstatic.net/bjuDY.png to ../images/76761795_bjuDY.png
# Downloaded https://i.sstatic.net/bjuDY.png to ../images/76761795_bjuDY.png
# ../images/77136986_RhR0G.png already exists, skipping
# Downloading https://i.sstatic.net/Bt7Mn.png to ../images/78053978_Bt7Mn.png
# Downloaded https://i.sstatic.net/Bt7Mn.png to ../images/78053978_Bt7Mn.png
# ../images/78349259_U0rgK.png already exists, skipping
# ../images/77230045_mS0MO.png already exists, skipping
# ../images/76896863_nsOse.png already exists, skipping
# Downloading https://i.sstatic.net/RjzB1.png to ../images/77019103_RjzB1.png
# Downloaded https://i.sstatic.net/RjzB1.png to ../images/77019103_RjzB1.png
# ../images/77065837_MHKjb.png already exists, skipping
# ../images/78516542_AJHflHm8.png already exists, skipping
# ../images/78516542_WiLTFMWw.png already exists, skipping
# ../images/78516542_nuaGV9IP.png already exists, skipping
# ../images/78516542_xVU9W5ni.png already exists, skipping
# Downloading https://i.sstatic.net/9GyrH.png to ../images/77255327_9GyrH.png
# Downloaded https://i.sstatic.net/9GyrH.png to ../images/77255327_9GyrH.png
# Downloading https://i.sstatic.net/7t2dv.png to ../images/77255327_7t2dv.png
# Downloaded https://i.sstatic.net/7t2dv.png to ../images/77255327_7t2dv.png
# ../images/78210207_UHQE7.png already exists, skipping
# Downloading https://i.sstatic.net/StBRs.png to ../images/78306470_StBRs.png
# Downloaded https://i.sstatic.net/StBRs.png to ../images/78306470_StBRs.png
# Downloading https://i.sstatic.net/wriWs.png to ../images/78306470_wriWs.png
# Downloaded https://i.sstatic.net/wriWs.png to ../images/78306470_wriWs.png
# Downloading https://i.sstatic.net/NL7Ew.png to ../images/78306470_NL7Ew.png
# Downloaded https://i.sstatic.net/NL7Ew.png to ../images/78306470_NL7Ew.png
# Downloading https://i.sstatic.net/QquUj.png to ../images/77339822_QquUj.png
# Downloaded https://i.sstatic.net/QquUj.png to ../images/77339822_QquUj.png
# ../images/77874491_vsmEq.png already exists, skipping
# ../images/77743222_KBe7c.png already exists, skipping
# ../images/77743222_17u0s.png already exists, skipping
# ../images/78366032_5BKgc.png already exists, skipping
# ../images/78366032_B2vSB.png already exists, skipping
# ../images/78216447_PQiqe.png already exists, skipping
# ../images/78216447_TaisO.png already exists, skipping
# ../images/77260958_xnkNb.png already exists, skipping
# ../images/77260958_wucrB.png already exists, skipping
# ../images/77732361_mX5L5.png already exists, skipping
# ../images/77063699_nXDBz.png already exists, skipping
# ../images/77063699_bcS5T.png already exists, skipping
# ../images/77063699_odIR0.png already exists, skipping
# ../images/78534409_AIfMud8J.png already exists, skipping
# Downloading https://i.sstatic.net/YJVWI.png to ../images/78374830_YJVWI.png
# Downloaded https://i.sstatic.net/YJVWI.png to ../images/78374830_YJVWI.png
# Downloading https://i.sstatic.net/zRgzP.png to ../images/78374830_zRgzP.png
# Downloaded https://i.sstatic.net/zRgzP.png to ../images/78374830_zRgzP.png
# Downloading https://i.sstatic.net/YgfX7.png to ../images/78374830_YgfX7.png
# Downloaded https://i.sstatic.net/YgfX7.png to ../images/78374830_YgfX7.png
# Downloading https://i.sstatic.net/E78QN.png to ../images/78374830_E78QN.png
# Downloaded https://i.sstatic.net/E78QN.png to ../images/78374830_E78QN.png
# Downloading https://i.sstatic.net/IscE9.png to ../images/78374830_IscE9.png
# Downloaded https://i.sstatic.net/IscE9.png to ../images/78374830_IscE9.png
# Downloading https://i.sstatic.net/N3kQD.png to ../images/78374830_N3kQD.png
# Downloaded https://i.sstatic.net/N3kQD.png to ../images/78374830_N3kQD.png
# Downloading https://i.sstatic.net/18m4R.png to ../images/77681798_18m4R.png
# Downloaded https://i.sstatic.net/18m4R.png to ../images/77681798_18m4R.png
# Downloading https://i.sstatic.net/eTmPr.png to ../images/77681798_eTmPr.png
# Downloaded https://i.sstatic.net/eTmPr.png to ../images/77681798_eTmPr.png
# Downloading https://i.sstatic.net/gnry4.png to ../images/77707149_gnry4.png
# Downloaded https://i.sstatic.net/gnry4.png to ../images/77707149_gnry4.png
# ../images/77707149_ssXXB.png already exists, skipping
# ../images/76830213_7YWSz.png already exists, skipping
# Downloading https://i.sstatic.net/4YQ66.png to ../images/77695363_4YQ66.png
# Downloaded https://i.sstatic.net/4YQ66.png to ../images/77695363_4YQ66.png
# Downloading https://i.sstatic.net/WqVc1.png to ../images/77695363_WqVc1.png
# Downloaded https://i.sstatic.net/WqVc1.png to ../images/77695363_WqVc1.png
# Downloading https://i.sstatic.net/nSods.png to ../images/77593166_nSods.png
# Downloaded https://i.sstatic.net/nSods.png to ../images/77593166_nSods.png
# ../images/77828139_ESGMF.png already exists, skipping
# Downloading https://i.sstatic.net/1KdX0.png to ../images/78211662_1KdX0.png
# Downloaded https://i.sstatic.net/1KdX0.png to ../images/78211662_1KdX0.png
# ../images/78346464_r3QU1.png already exists, skipping
# ../images/78346464_ar70A.png already exists, skipping
# Downloading https://i.sstatic.net/FkZgP.png to ../images/78074694_FkZgP.png
# Downloaded https://i.sstatic.net/FkZgP.png to ../images/78074694_FkZgP.png
# Downloading https://i.sstatic.net/pBNYd89f.png to ../images/78457396_pBNYd89f.png
# Downloaded https://i.sstatic.net/pBNYd89f.png to ../images/78457396_pBNYd89f.png
# Downloading https://i.sstatic.net/ms1Ka.png to ../images/77910270_ms1Ka.png
# Downloaded https://i.sstatic.net/ms1Ka.png to ../images/77910270_ms1Ka.png
# ../images/78345648_7YImp.png already exists, skipping
# ../images/78345648_y4Dux.png already exists, skipping
# ../images/77536673_s2TcK.png already exists, skipping
# ../images/77536673_BGKcr.png already exists, skipping
# ../images/77536673_zQObZ.png already exists, skipping
# Downloading https://i.sstatic.net/VQBff.png to ../images/77305228_VQBff.png
# Downloaded https://i.sstatic.net/VQBff.png to ../images/77305228_VQBff.png
# ../images/77095803_mCjny.png already exists, skipping
# ../images/77196881_95BNh.png already exists, skipping
# ../images/78400822_cWRDesOg.png already exists, skipping
# ../images/78400822_oTO1giZA.png already exists, skipping
# ../images/78400822_65h1EZpB.png already exists, skipping
# ../images/78400822_LhGJ8GLd.png already exists, skipping
# ../images/78400822_3KK6eRwl.png already exists, skipping
# ../images/78400822_QsUkb1An.png already exists, skipping
# ../images/77847162_2s8qC.png already exists, skipping
# ../images/77847162_TYuOZ.png already exists, skipping
# ../images/77847162_C3QMK.png already exists, skipping
# ../images/77847162_A3idV.png already exists, skipping
# ../images/78173810_PoAAz.png already exists, skipping
# ../images/78160155_hmo1t.png already exists, skipping
# ../images/78246970_xcFXq.png already exists, skipping
# ../images/77140995_Sc3sT.png already exists, skipping
# ../images/77140995_lg3SY.png already exists, skipping
# Downloading https://i.sstatic.net/OOjZY.png to ../images/76827940_OOjZY.png
# Downloaded https://i.sstatic.net/OOjZY.png to ../images/76827940_OOjZY.png
# ../images/78265558_SIi3q.png already exists, skipping
# ../images/78265558_fyzTv.png already exists, skipping
# Downloading https://i.sstatic.net/VQaya.png to ../images/78117643_VQaya.png
# Downloaded https://i.sstatic.net/VQaya.png to ../images/78117643_VQaya.png
# Downloading https://i.sstatic.net/QbuDM.png to ../images/78168372_QbuDM.png
# Downloaded https://i.sstatic.net/QbuDM.png to ../images/78168372_QbuDM.png
# Downloading https://i.sstatic.net/ydvH5.png to ../images/78217637_ydvH5.png
# Downloaded https://i.sstatic.net/ydvH5.png to ../images/78217637_ydvH5.png
# ../images/78037297_IQRQQ.png already exists, skipping
# ../images/77138141_xpMz0.png already exists, skipping
# ../images/77462878_DpfEs.png already exists, skipping
# Downloading https://i.sstatic.net/NW31t.jpg to ../images/78001351_NW31t.png
# Downloaded https://i.sstatic.net/NW31t.jpg to ../images/78001351_NW31t.png
# Downloading https://i.sstatic.net/P1uLp.png to ../images/77394432_P1uLp.png
# Downloaded https://i.sstatic.net/P1uLp.png to ../images/77394432_P1uLp.png
# Downloading https://i.sstatic.net/uKUAw.png to ../images/77394432_uKUAw.png
# Downloaded https://i.sstatic.net/uKUAw.png to ../images/77394432_uKUAw.png
# Downloading https://i.sstatic.net/ItjMX.png to ../images/77934935_ItjMX.png
# Downloaded https://i.sstatic.net/ItjMX.png to ../images/77934935_ItjMX.png
# ../images/76908538_gSFIf.png already exists, skipping
# ../images/78579273_M6zqo9sp.png already exists, skipping
# ../images/78579273_Gsxex7iQ.png already exists, skipping
# ../images/77962334_Dtc3q.png already exists, skipping
# ../images/77962334_OI1WB.png already exists, skipping
# ../images/77962334_jNBwM.png already exists, skipping
# ../images/76956754_mahQH.png already exists, skipping
# ../images/76920928_z6bRI.png already exists, skipping
# Downloading https://i.sstatic.net/e864n.png to ../images/77946460_e864n.png
# Downloaded https://i.sstatic.net/e864n.png to ../images/77946460_e864n.png
# ../images/78005283_mG5xq.png already exists, skipping
# ../images/78263141_x2Dzp.png already exists, skipping
# ../images/78263141_nx5rS.png already exists, skipping
# ../images/76824253_XIuU3.png already exists, skipping
# ../images/76824253_rTCYA.png already exists, skipping
# Downloading https://i.sstatic.net/wgqfl.png to ../images/77930342_wgqfl.png
# Downloaded https://i.sstatic.net/wgqfl.png to ../images/77930342_wgqfl.png
# ../images/78399741_vqNBjZo7.png already exists, skipping
# ../images/77255038_3XJZD.png already exists, skipping
# ../images/77255038_LN2cu.png already exists, skipping
# ../images/77255038_K5YRk.png already exists, skipping
# ../images/78496028_8MGBS0kT.png already exists, skipping
# Downloading https://i.sstatic.net/uqwgo.jpg to ../images/77101040_uqwgo.png
# Downloaded https://i.sstatic.net/uqwgo.jpg to ../images/77101040_uqwgo.png
# ../images/77851628_fyAt0.png already exists, skipping
# ../images/77851628_uZu3l.png already exists, skipping
# ../images/78563781_pBOjgu9f.png already exists, skipping
# ../images/78563781_UDBWPXhE.png already exists, skipping
# ../images/77710405_ZG9qZ.png already exists, skipping
# Downloading https://i.sstatic.net/lkNZm.png to ../images/77710405_lkNZm.png
# Downloaded https://i.sstatic.net/lkNZm.png to ../images/77710405_lkNZm.png
# Downloading https://i.sstatic.net/OQXCV.png to ../images/77710405_OQXCV.png
# Downloaded https://i.sstatic.net/OQXCV.png to ../images/77710405_OQXCV.png
# Downloading https://i.sstatic.net/BHUbZiMz.png to ../images/78651289_BHUbZiMz.png
# Downloaded https://i.sstatic.net/BHUbZiMz.png to ../images/78651289_BHUbZiMz.png
# Downloading https://i.sstatic.net/wZ871.png to ../images/77099853_wZ871.png
# Downloaded https://i.sstatic.net/wZ871.png to ../images/77099853_wZ871.png
# Downloading https://i.sstatic.net/DXPEi.png to ../images/77652151_DXPEi.png
# Downloaded https://i.sstatic.net/DXPEi.png to ../images/77652151_DXPEi.png
# Downloading https://i.sstatic.net/XG9u1.png to ../images/77652151_XG9u1.png
# Downloaded https://i.sstatic.net/XG9u1.png to ../images/77652151_XG9u1.png
# Downloading https://i.sstatic.net/1TdITt3L.png to ../images/78545145_1TdITt3L.png
# Downloaded https://i.sstatic.net/1TdITt3L.png to ../images/78545145_1TdITt3L.png
# Downloading https://i.sstatic.net/PpfEz.png to ../images/77110765_PpfEz.png
# Downloaded https://i.sstatic.net/PpfEz.png to ../images/77110765_PpfEz.png
# Downloading https://i.sstatic.net/KSoJy.png to ../images/78048830_KSoJy.png
# Downloaded https://i.sstatic.net/KSoJy.png to ../images/78048830_KSoJy.png
# Downloading https://i.sstatic.net/jbEaWaFd.png to ../images/78575851_jbEaWaFd.png
# Downloaded https://i.sstatic.net/jbEaWaFd.png to ../images/78575851_jbEaWaFd.png
# ../images/78575851_pBhSV4Cf.png already exists, skipping
# Downloading https://i.sstatic.net/jFovz.png to ../images/77677015_jFovz.png
# Downloaded https://i.sstatic.net/jFovz.png to ../images/77677015_jFovz.png
# ../images/77677015_TyBQK.png already exists, skipping
# ../images/76789778_131rS.png already exists, skipping
# ../images/77725934_0Yw7Y.png already exists, skipping
# ../images/77725934_Kh2C0.png already exists, skipping
# ../images/77113588_SEoR2.png already exists, skipping
# Downloading https://i.sstatic.net/D46Bv.png to ../images/78153171_D46Bv.png
# Downloaded https://i.sstatic.net/D46Bv.png to ../images/78153171_D46Bv.png
# Downloading https://i.sstatic.net/K9L3h.png to ../images/77630765_K9L3h.png
# Downloaded https://i.sstatic.net/K9L3h.png to ../images/77630765_K9L3h.png
# ../images/77630765_YeXrq.png already exists, skipping
# ../images/78515470_oTmQWNpA.png already exists, skipping
# ../images/77509746_YlHcV.png already exists, skipping
# ../images/77076052_MJWwW.png already exists, skipping
# ../images/77076052_W7nWG.png already exists, skipping
# Downloading https://i.sstatic.net/TMkrsNhJ.png to ../images/78487793_TMkrsNhJ.png
# Downloaded https://i.sstatic.net/TMkrsNhJ.png to ../images/78487793_TMkrsNhJ.png
# ../images/77643789_gwRWz.png already exists, skipping
# Downloading https://i.sstatic.net/TzwrT.png to ../images/76986564_TzwrT.png
# Downloaded https://i.sstatic.net/TzwrT.png to ../images/76986564_TzwrT.png
# Downloading https://i.sstatic.net/TlUVt.png to ../images/76986564_TlUVt.png
# Downloaded https://i.sstatic.net/TlUVt.png to ../images/76986564_TlUVt.png
# Downloading https://i.sstatic.net/dRLtu.png to ../images/76986564_dRLtu.png
# Downloaded https://i.sstatic.net/dRLtu.png to ../images/76986564_dRLtu.png
# Downloading https://i.sstatic.net/d9aHZ.png to ../images/77990301_d9aHZ.png
# Downloaded https://i.sstatic.net/d9aHZ.png to ../images/77990301_d9aHZ.png
# Downloading https://i.sstatic.net/IiUDc.png to ../images/77990301_IiUDc.png
# Downloaded https://i.sstatic.net/IiUDc.png to ../images/77990301_IiUDc.png
# Downloading https://i.sstatic.net/nspCc.png to ../images/77990301_nspCc.png
# Downloaded https://i.sstatic.net/nspCc.png to ../images/77990301_nspCc.png
# ../images/77962484_561PY.png already exists, skipping
# ../images/77962484_kdFnt.png already exists, skipping
# ../images/77962484_FjtDN.png already exists, skipping
# Downloading https://i.sstatic.net/lfTlt.png to ../images/76838494_lfTlt.png
# Downloaded https://i.sstatic.net/lfTlt.png to ../images/76838494_lfTlt.png
# ../images/77179475_MzK1i.png already exists, skipping
# ../images/78084385_fbNxe.png already exists, skipping
# ../images/77017481_hMcsh.png already exists, skipping
# ../images/77770634_B1qnY.png already exists, skipping
# ../images/77770634_B4GVH.png already exists, skipping
# Downloading https://i.sstatic.net/e6E2u.png to ../images/77071865_e6E2u.png
# Downloaded https://i.sstatic.net/e6E2u.png to ../images/77071865_e6E2u.png
# ../images/78124197_u2sCZ.png already exists, skipping
# Downloading https://i.sstatic.net/bYMub.png to ../images/77443620_bYMub.png
# Downloaded https://i.sstatic.net/bYMub.png to ../images/77443620_bYMub.png
# ../images/77443620_Obd61.png already exists, skipping
# ../images/76865842_s0SEJ.png already exists, skipping
# ../images/76865842_WYVnB.png already exists, skipping
# ../images/76865842_QhoRt.png already exists, skipping
# ../images/77532287_xNhOo.png already exists, skipping
# Downloading https://i.sstatic.net/oTsC1.png to ../images/78367675_oTsC1.png
# Downloaded https://i.sstatic.net/oTsC1.png to ../images/78367675_oTsC1.png
# ../images/76759311_ECauI.png already exists, skipping
# Downloading https://i.sstatic.net/qlhum.png to ../images/77768454_qlhum.png
# Downloaded https://i.sstatic.net/qlhum.png to ../images/77768454_qlhum.png
# Downloading https://i.sstatic.net/vsYmx.png to ../images/77768454_vsYmx.png
# Downloaded https://i.sstatic.net/vsYmx.png to ../images/77768454_vsYmx.png
# ../images/78564196_Zn3YF7mS.png already exists, skipping
# ../images/78581396_oFPdfSA4.png already exists, skipping
# ../images/77276571_eOMSX.png already exists, skipping
# ../images/76953144_0EFeo.png already exists, skipping
# ../images/78069061_evUpO.png already exists, skipping
# Downloading https://i.sstatic.net/MBcDxLcp.png to ../images/78434331_MBcDxLcp.png
# Downloaded https://i.sstatic.net/MBcDxLcp.png to ../images/78434331_MBcDxLcp.png
# ../images/76931763_BsXGe.png already exists, skipping
# Downloading https://i.sstatic.net/JCLa6.png to ../images/77272166_JCLa6.png
# Downloaded https://i.sstatic.net/JCLa6.png to ../images/77272166_JCLa6.png
# Downloading https://i.sstatic.net/3otiS.png to ../images/77272166_3otiS.png
# Downloaded https://i.sstatic.net/3otiS.png to ../images/77272166_3otiS.png
# Downloading https://i.sstatic.net/cm5J4.png to ../images/77272166_cm5J4.png
# Downloaded https://i.sstatic.net/cm5J4.png to ../images/77272166_cm5J4.png
# Downloading https://i.sstatic.net/yQhGN.png to ../images/77272166_yQhGN.png
# Downloaded https://i.sstatic.net/yQhGN.png to ../images/77272166_yQhGN.png
# Downloading https://i.sstatic.net/E5iOL.png to ../images/77272166_E5iOL.png
# Downloaded https://i.sstatic.net/E5iOL.png to ../images/77272166_E5iOL.png
# ../images/78061600_ao99X.png already exists, skipping
# ../images/77221640_MrPuy.png already exists, skipping
# ../images/77055506_WBK3g.png already exists, skipping
# ../images/77965787_9DOZe.png already exists, skipping
# ../images/77965787_d2C51.png already exists, skipping
# ../images/77753534_UtaJi.png already exists, skipping
# ../images/77753534_nNeq5.png already exists, skipping
# Downloading https://i.sstatic.net/BOiYP.png to ../images/77244845_BOiYP.png
# Downloaded https://i.sstatic.net/BOiYP.png to ../images/77244845_BOiYP.png
# ../images/77244845_EKjaF.png already exists, skipping
# Downloading https://i.sstatic.net/5tr5T.png to ../images/77244845_5tr5T.png
# Downloaded https://i.sstatic.net/5tr5T.png to ../images/77244845_5tr5T.png
# ../images/77244845_vCkbJ.png already exists, skipping
# Downloading https://i.sstatic.net/vThnX.png to ../images/77244845_vThnX.png
# Downloaded https://i.sstatic.net/vThnX.png to ../images/77244845_vThnX.png
# Downloading https://i.sstatic.net/6prPk.png to ../images/77786831_6prPk.png
# Downloaded https://i.sstatic.net/6prPk.png to ../images/77786831_6prPk.png
# Downloading https://i.sstatic.net/WxvnAEAw.png to ../images/78627941_WxvnAEAw.png
# Downloaded https://i.sstatic.net/WxvnAEAw.png to ../images/78627941_WxvnAEAw.png
# ../images/77807895_fSgiB.png already exists, skipping
# ../images/78689138_UmhZ9zHE.png already exists, skipping
# ../images/78689138_tCbdO86y.png already exists, skipping
# ../images/78207988_TBLS0.png already exists, skipping
# ../images/78193572_tYK1L.png already exists, skipping
# ../images/78193572_x73qK.png already exists, skipping
# ../images/78002827_BzNNb.png already exists, skipping
# Downloading https://i.sstatic.net/GDY6d.png to ../images/78002827_GDY6d.png
# Downloaded https://i.sstatic.net/GDY6d.png to ../images/78002827_GDY6d.png
# ../images/78198076_Pao9O.png already exists, skipping
# ../images/77227541_anIBx.png already exists, skipping
# Downloading https://i.sstatic.net/dtHW7.png to ../images/77227541_dtHW7.png
# Downloaded https://i.sstatic.net/dtHW7.png to ../images/77227541_dtHW7.png
# ../images/78352608_LSIzC.png already exists, skipping
# Downloading https://i.sstatic.net/0cc45.png to ../images/77517616_0cc45.png
# Downloaded https://i.sstatic.net/0cc45.png to ../images/77517616_0cc45.png
# ../images/76796881_kuEQz.png already exists, skipping
# ../images/76796881_lQHjh.png already exists, skipping
# Downloading https://i.sstatic.net/so8N2.png to ../images/78263931_so8N2.png
# Downloaded https://i.sstatic.net/so8N2.png to ../images/78263931_so8N2.png
# ../images/78363878_bLoIv.png already exists, skipping
# ../images/78363878_8CJ73.png already exists, skipping
# Downloading https://i.sstatic.net/cXuLb.png to ../images/76896814_cXuLb.png
# Downloaded https://i.sstatic.net/cXuLb.png to ../images/76896814_cXuLb.png
# ../images/76896814_ED17D.png already exists, skipping
# ../images/78669581_EDinwvQZ.png already exists, skipping
# ../images/78669581_HPf39nOy.png already exists, skipping
# ../images/78669581_2YVzQNM6.png already exists, skipping
# Downloading https://i.sstatic.net/sNaaD.png to ../images/77163651_sNaaD.png
# Downloaded https://i.sstatic.net/sNaaD.png to ../images/77163651_sNaaD.png
# ../images/76993965_0EXaB.png already exists, skipping
# ../images/78543252_u5NE9.png already exists, skipping
# ../images/78543252_JGY6O.png already exists, skipping
# Downloading https://i.sstatic.net/vbNv4.png to ../images/77488509_vbNv4.png
# Downloaded https://i.sstatic.net/vbNv4.png to ../images/77488509_vbNv4.png
# ../images/77246301_Ad0xG.png already exists, skipping
# ../images/77246301_ddzv7.png already exists, skipping
# ../images/78498411_VNmvCgth.png already exists, skipping
# Downloading https://i.sstatic.net/xJ3EaqiI.png to ../images/78601547_xJ3EaqiI.png
# Downloaded https://i.sstatic.net/xJ3EaqiI.png to ../images/78601547_xJ3EaqiI.png
# Downloading https://i.sstatic.net/1KC4yze3.png to ../images/78601547_1KC4yze3.png
# Downloaded https://i.sstatic.net/1KC4yze3.png to ../images/78601547_1KC4yze3.png
# Downloading https://i.sstatic.net/bwGnk.png to ../images/77097547_bwGnk.png
# Downloaded https://i.sstatic.net/bwGnk.png to ../images/77097547_bwGnk.png
# ../images/77283629_ZTsvW.png already exists, skipping
# ../images/78552433_Eh9Ob8ZP.png already exists, skipping
# Downloading https://i.sstatic.net/nInNT.jpg to ../images/77867794_nInNT.png
# Downloaded https://i.sstatic.net/nInNT.jpg to ../images/77867794_nInNT.png
# Downloading https://i.sstatic.net/r65Hr.jpg to ../images/77867794_r65Hr.png
# Downloaded https://i.sstatic.net/r65Hr.jpg to ../images/77867794_r65Hr.png
# ../images/77852609_TAY8P.png already exists, skipping
# Downloading https://i.sstatic.net/DEOy1.png to ../images/77751123_DEOy1.png
# Downloaded https://i.sstatic.net/DEOy1.png to ../images/77751123_DEOy1.png
# Downloading https://i.sstatic.net/MjtVu.png to ../images/77751123_MjtVu.png
# Downloaded https://i.sstatic.net/MjtVu.png to ../images/77751123_MjtVu.png
# ../images/78253869_iMt5C.png already exists, skipping
# ../images/78395537_yk8CvUT0.png already exists, skipping
# Downloading https://i.sstatic.net/Xlb88pcg.png to ../images/78502335_Xlb88pcg.png
# Downloaded https://i.sstatic.net/Xlb88pcg.png to ../images/78502335_Xlb88pcg.png
# Downloading https://i.sstatic.net/kEP3fDZb.png to ../images/78502335_kEP3fDZb.png
# Downloaded https://i.sstatic.net/kEP3fDZb.png to ../images/78502335_kEP3fDZb.png
# Downloading https://i.sstatic.net/1KblBeV3.png to ../images/78463606_1KblBeV3.png
# Downloaded https://i.sstatic.net/1KblBeV3.png to ../images/78463606_1KblBeV3.png
# Downloading https://i.sstatic.net/1e1C4C3L.png to ../images/78463606_1e1C4C3L.png
# Downloaded https://i.sstatic.net/1e1C4C3L.png to ../images/78463606_1e1C4C3L.png
# Downloading https://i.sstatic.net/WDeq8.jpg to ../images/77710238_WDeq8.png
# Downloaded https://i.sstatic.net/WDeq8.jpg to ../images/77710238_WDeq8.png
# ../images/77710238_l9rJ8.png already exists, skipping
# Downloading https://i.sstatic.net/9sDhB.jpg to ../images/77710238_9sDhB.png
# Downloaded https://i.sstatic.net/9sDhB.jpg to ../images/77710238_9sDhB.png
# ../images/78576486_82n6sDDT.png already exists, skipping
# ../images/77686492_Za97I.png already exists, skipping
# Downloading https://i.sstatic.net/n6nxK.png to ../images/77686492_n6nxK.png
# Downloaded https://i.sstatic.net/n6nxK.png to ../images/77686492_n6nxK.png
# ../images/76867552_P1cCC.png already exists, skipping
# Downloading https://i.sstatic.net/OGnTe.png to ../images/77861240_OGnTe.png
# Downloaded https://i.sstatic.net/OGnTe.png to ../images/77861240_OGnTe.png
# ../images/78161963_PAtwH.png already exists, skipping
# ../images/77163350_vNlMz.png already exists, skipping
# ../images/77038585_BOCMY.png already exists, skipping
# Downloading https://i.sstatic.net/6WOlp.png to ../images/77888376_6WOlp.png
# Downloaded https://i.sstatic.net/6WOlp.png to ../images/77888376_6WOlp.png
# Downloading https://i.sstatic.net/SYHsl.png to ../images/77888376_SYHsl.png
# Downloaded https://i.sstatic.net/SYHsl.png to ../images/77888376_SYHsl.png
# ../images/78432698_UdTzXLED.png already exists, skipping
# ../images/78432698_ohDixxA4.png already exists, skipping
# ../images/78432698_mLyh5GQD.png already exists, skipping
# ../images/78432698_pzH8uePf.png already exists, skipping
# ../images/78432698_numRxadP.png already exists, skipping
# ../images/77463642_u9fK4.png already exists, skipping
# Downloading https://i.sstatic.net/YPUGn.png to ../images/78164694_YPUGn.png
# Downloaded https://i.sstatic.net/YPUGn.png to ../images/78164694_YPUGn.png
# ../images/77957949_0pTPz.png already exists, skipping
# ../images/77340860_vJYqt.png already exists, skipping
# ../images/77835464_kgJQW.png already exists, skipping
# Downloading https://i.sstatic.net/J9tw8.png to ../images/77658415_J9tw8.png
# Downloaded https://i.sstatic.net/J9tw8.png to ../images/77658415_J9tw8.png
# ../images/76841763_AxLOo.png already exists, skipping
# ../images/78242976_6Ogyr.png already exists, skipping
# Downloading https://i.sstatic.net/Z3Ec7.png to ../images/78279995_Z3Ec7.png
# Downloaded https://i.sstatic.net/Z3Ec7.png to ../images/78279995_Z3Ec7.png
# ../images/78279995_peGfR.png already exists, skipping
# ../images/77262928_gBzCe.png already exists, skipping
# ../images/77262928_xdp3J.png already exists, skipping
# ../images/77262928_kaEdX.png already exists, skipping
# ../images/77798028_uzKdO.png already exists, skipping
# ../images/77326308_VNgYp.png already exists, skipping
# Downloading https://i.sstatic.net/l8CCD.jpg to ../images/77060816_l8CCD.png
# Downloaded https://i.sstatic.net/l8CCD.jpg to ../images/77060816_l8CCD.png
# ../images/77990646_0pE2s.png already exists, skipping
# ../images/78273983_C66RK.png already exists, skipping
# ../images/78273983_btSxH.png already exists, skipping
# ../images/78273983_y8p7j.png already exists, skipping
# ../images/77031119_W8e4r.png already exists, skipping
# ../images/77018636_X4RbI.png already exists, skipping
# ../images/77184370_toz8J.png already exists, skipping
# ../images/77184370_FxuFc.png already exists, skipping
# Downloading https://i.sstatic.net/sq7Kq.png to ../images/78078192_sq7Kq.png
# Downloaded https://i.sstatic.net/sq7Kq.png to ../images/78078192_sq7Kq.png
# Downloading https://i.sstatic.net/Tv6ae.jpg to ../images/77614004_Tv6ae.png
# Downloaded https://i.sstatic.net/Tv6ae.jpg to ../images/77614004_Tv6ae.png
# ../images/77384279_lcvKM.png already exists, skipping
# ../images/78071479_LtLjN.png already exists, skipping
# Downloading https://i.sstatic.net/rIpgJ.png to ../images/77670443_rIpgJ.png
# Downloaded https://i.sstatic.net/rIpgJ.png to ../images/77670443_rIpgJ.png
# Downloading https://i.sstatic.net/Kd1u3.png to ../images/78026282_Kd1u3.png
# Downloaded https://i.sstatic.net/Kd1u3.png to ../images/78026282_Kd1u3.png
# Downloading https://i.sstatic.net/F9MKG.png to ../images/77420573_F9MKG.png
# Downloaded https://i.sstatic.net/F9MKG.png to ../images/77420573_F9MKG.png
# Downloading https://i.sstatic.net/K7bCe.png to ../images/77420573_K7bCe.png
# Downloaded https://i.sstatic.net/K7bCe.png to ../images/77420573_K7bCe.png
# ../images/77420573_DeUnP.png already exists, skipping
# Downloading https://i.sstatic.net/C2BFh.png to ../images/77103696_C2BFh.png
# Downloaded https://i.sstatic.net/C2BFh.png to ../images/77103696_C2BFh.png
# ../images/78098874_R7dwa.png already exists, skipping
# ../images/77280122_fOHZH.png already exists, skipping
# ../images/78627783_JfMkMKr2.png already exists, skipping
# ../images/78618183_LRoUeP8d.png already exists, skipping
# ../images/78618183_65ugzbMB.png already exists, skipping
# ../images/78618183_exRrGHvI.png already exists, skipping
# ../images/78618183_AJ531Gp8.png already exists, skipping
# ../images/78618183_mLEnqugD.png already exists, skipping
# ../images/78460326_pBz6iCMf.png already exists, skipping
# Downloading https://i.sstatic.net/psdqI.png to ../images/78294410_psdqI.png
# Downloaded https://i.sstatic.net/psdqI.png to ../images/78294410_psdqI.png
# ../images/77162082_RxZiB.png already exists, skipping
# Downloading https://i.sstatic.net/G5weg.png to ../images/76894916_G5weg.png
# Downloaded https://i.sstatic.net/G5weg.png to ../images/76894916_G5weg.png
# ../images/76894916_wkTZv.png already exists, skipping
# Downloading https://i.sstatic.net/M53mW.jpg to ../images/77931494_M53mW.png
# Downloaded https://i.sstatic.net/M53mW.jpg to ../images/77931494_M53mW.png
# Downloading https://i.sstatic.net/c9vX1.jpg to ../images/77931494_c9vX1.png
# Downloaded https://i.sstatic.net/c9vX1.jpg to ../images/77931494_c9vX1.png
# ../images/76925077_1RgC3.png already exists, skipping
# Downloading https://i.sstatic.net/1SMt9.png to ../images/76925077_1SMt9.png
# Downloaded https://i.sstatic.net/1SMt9.png to ../images/76925077_1SMt9.png
# ../images/77679289_WP2xm.png already exists, skipping
# ../images/77517845_pTHVE.png already exists, skipping
# ../images/78669597_VEcGmxth.png already exists, skipping
# ../images/77497417_ZiKNA.png already exists, skipping
# ../images/77497417_tlYK1.png already exists, skipping
# Downloading https://i.sstatic.net/ZBW9S.png to ../images/77856962_ZBW9S.png
# Downloaded https://i.sstatic.net/ZBW9S.png to ../images/77856962_ZBW9S.png
# ../images/77915481_tkJzn.png already exists, skipping
# ../images/78289972_t0B6Y.png already exists, skipping
# Downloading https://i.sstatic.net/ptJja0fg.png to ../images/78436228_ptJja0fg.png
# Downloaded https://i.sstatic.net/ptJja0fg.png to ../images/78436228_ptJja0fg.png
# ../images/76985347_ZWjZa.png already exists, skipping
# Downloading https://i.sstatic.net/Yt85N.png to ../images/77976105_Yt85N.png
# Downloaded https://i.sstatic.net/Yt85N.png to ../images/77976105_Yt85N.png
# ../images/77107958_eou6v.png already exists, skipping
# Downloading https://i.sstatic.net/k4Ip7.png to ../images/77107958_k4Ip7.png
# Downloaded https://i.sstatic.net/k4Ip7.png to ../images/77107958_k4Ip7.png
# Downloading https://i.sstatic.net/jEorZ.png to ../images/77107958_jEorZ.png
# Downloaded https://i.sstatic.net/jEorZ.png to ../images/77107958_jEorZ.png
# ../images/77678151_3KnUx.png already exists, skipping
# ../images/77678151_37A41.png already exists, skipping
# ../images/76899742_uKqP5.png already exists, skipping
# ../images/76982180_TQSo2.png already exists, skipping
# Downloading https://i.sstatic.net/6HVcpnWB.png to ../images/78647293_6HVcpnWB.png
# Downloaded https://i.sstatic.net/6HVcpnWB.png to ../images/78647293_6HVcpnWB.png
# Downloading https://i.sstatic.net/xSUUn.png to ../images/77682602_xSUUn.png
# Downloaded https://i.sstatic.net/xSUUn.png to ../images/77682602_xSUUn.png
# ../images/78117303_jelEF.png already exists, skipping
# Downloading https://i.sstatic.net/SRhfQ.png to ../images/78117303_SRhfQ.png
# Downloaded https://i.sstatic.net/SRhfQ.png to ../images/78117303_SRhfQ.png
# Downloading https://i.sstatic.net/1967iip3.png to ../images/78638246_1967iip3.png
# Downloaded https://i.sstatic.net/1967iip3.png to ../images/78638246_1967iip3.png
# ../images/77921843_Vk1UG.png already exists, skipping
# ../images/77921843_4jV3G.png already exists, skipping
# ../images/77921843_ak4QP.png already exists, skipping
# ../images/77671053_NUT83.png already exists, skipping
# ../images/77671053_xsm7o.png already exists, skipping
# ../images/77425963_NEOCw.png already exists, skipping
# ../images/77425963_4DNEI.png already exists, skipping
# ../images/77891148_9EdlH.png already exists, skipping
# ../images/77891148_D1FFt.png already exists, skipping
# ../images/77891148_rqt5r.png already exists, skipping
# ../images/77891148_SrUyh.png already exists, skipping
# ../images/78672616_531yzoCH.png already exists, skipping
# Downloading https://i.sstatic.net/BH746fHz.png to ../images/78420144_BH746fHz.png
# Downloaded https://i.sstatic.net/BH746fHz.png to ../images/78420144_BH746fHz.png
# Downloading https://i.sstatic.net/0OkQJ8CY.png to ../images/78420144_0OkQJ8CY.png
# Downloaded https://i.sstatic.net/0OkQJ8CY.png to ../images/78420144_0OkQJ8CY.png
# Downloading https://i.sstatic.net/hIChS.png to ../images/78046442_hIChS.png
# Downloaded https://i.sstatic.net/hIChS.png to ../images/78046442_hIChS.png
# ../images/78374123_oeYg1.png already exists, skipping
# ../images/77765874_57q57.png already exists, skipping
# ../images/77765874_XEuz9.png already exists, skipping
# Downloading https://i.sstatic.net/Y9j7Fcx7.png to ../images/78617443_Y9j7Fcx7.png
# Downloaded https://i.sstatic.net/Y9j7Fcx7.png to ../images/78617443_Y9j7Fcx7.png
# ../images/76771084_Hnl1n.png already exists, skipping
# Downloading https://i.sstatic.net/hCG6A.png to ../images/77690865_hCG6A.png
# Downloaded https://i.sstatic.net/hCG6A.png to ../images/77690865_hCG6A.png
# Downloading https://i.sstatic.net/u31Pc.png to ../images/77690865_u31Pc.png
# Downloaded https://i.sstatic.net/u31Pc.png to ../images/77690865_u31Pc.png
# ../images/78445940_vdLi4jo7.png already exists, skipping
# ../images/78445940_OlYy7Hv1.png already exists, skipping
# Downloading https://i.sstatic.net/Q7Imr.png to ../images/78219773_Q7Imr.png
# Downloaded https://i.sstatic.net/Q7Imr.png to ../images/78219773_Q7Imr.png
# Downloading https://i.sstatic.net/u4aQS.png to ../images/78219773_u4aQS.png
# Downloaded https://i.sstatic.net/u4aQS.png to ../images/78219773_u4aQS.png
# Downloading https://i.sstatic.net/o0icq.png to ../images/78219773_o0icq.png
# Downloaded https://i.sstatic.net/o0icq.png to ../images/78219773_o0icq.png
# Downloading https://i.sstatic.net/yhBrJ.png to ../images/78219773_yhBrJ.png
# Downloaded https://i.sstatic.net/yhBrJ.png to ../images/78219773_yhBrJ.png
# ../images/76940845_vyTbt.png already exists, skipping
# ../images/78264889_UCuDR.png already exists, skipping
# ../images/78264889_Q7sPt.png already exists, skipping
# Downloading https://i.sstatic.net/6xR18.png to ../images/77091097_6xR18.png
# Downloaded https://i.sstatic.net/6xR18.png to ../images/77091097_6xR18.png
# Downloading https://i.sstatic.net/nSMZWX2P.png to ../images/78533361_nSMZWX2P.png
# Downloaded https://i.sstatic.net/nSMZWX2P.png to ../images/78533361_nSMZWX2P.png
# ../images/78151248_ymXkk.png already exists, skipping
# ../images/78151248_jxMKE.png already exists, skipping
# ../images/78151248_AMS3E.png already exists, skipping
# ../images/78151248_mbHfA.png already exists, skipping
# ../images/78151248_dMI3d.png already exists, skipping
# Downloading https://i.sstatic.net/m5ixV.png to ../images/78010772_m5ixV.png
# Downloaded https://i.sstatic.net/m5ixV.png to ../images/78010772_m5ixV.png
# ../images/77345219_S8joJ.png already exists, skipping
# ../images/77345219_L2jBe.png already exists, skipping
# ../images/77345219_EjZcW.png already exists, skipping
# ../images/77345219_tpcdD.png already exists, skipping
# ../images/77054208_5Qlm7.png already exists, skipping
# ../images/77054208_QxdcV.png already exists, skipping
# Downloading https://i.sstatic.net/MswJj.png to ../images/77696958_MswJj.png
# Downloaded https://i.sstatic.net/MswJj.png to ../images/77696958_MswJj.png
# ../images/77696958_b1oE9.png already exists, skipping
# Downloading https://i.sstatic.net/8T0Dx.png to ../images/76934131_8T0Dx.png
# Downloaded https://i.sstatic.net/8T0Dx.png to ../images/76934131_8T0Dx.png
# ../images/78578763_OJnkw018.png already exists, skipping
# ../images/78480062_FMgSmTVo.png already exists, skipping
# ../images/76839891_EsjrJ.png already exists, skipping
# ...
# Downloading https://i.sstatic.net/2MeBK.png to ../images/77268448_2MeBK.png
# Downloaded https://i.sstatic.net/2MeBK.png to ../images/77268448_2MeBK.png
# Downloading https://i.sstatic.net/RoXTs.png to ../images/77215374_RoXTs.png
# Downloaded https://i.sstatic.net/RoXTs.png to ../images/77215374_RoXTs.png
# ../images/77993850_YKvR7.png already exists, skipping
# ../images/78278459_lDCz8.png already exists, skipping
# ../images/77883401_gqhte.png already exists, skipping
# Downloading https://i.sstatic.net/O8Wew.png to ../images/77810928_O8Wew.png
# Downloaded https://i.sstatic.net/O8Wew.png to ../images/77810928_O8Wew.png
# Downloading https://i.sstatic.net/jCKVf.png to ../images/78337687_jCKVf.png
# Downloaded https://i.sstatic.net/jCKVf.png to ../images/78337687_jCKVf.png
# ../images/78019241_AzOvy.png already exists, skipping
# ../images/78019241_8El9z.png already exists, skipping
# Downloading https://i.sstatic.net/9nF6vUFK.png to ../images/78678692_9nF6vUFK.png
# Downloaded https://i.sstatic.net/9nF6vUFK.png to ../images/78678692_9nF6vUFK.png
# ../images/78398092_oWiPTuA4.png already exists, skipping
# Downloading https://i.sstatic.net/EAGJOiZP.png to ../images/78398092_EAGJOiZP.png
# Downloaded https://i.sstatic.net/EAGJOiZP.png to ../images/78398092_EAGJOiZP.png
# ../images/77500239_rLQhp.png already exists, skipping
# ../images/78628317_YjEVaAXx.png already exists, skipping
# ../images/78257324_8wMXH.png already exists, skipping
# ../images/77206992_GGeX3.png already exists, skipping
# ../images/78240100_e9wkK.png already exists, skipping
# ../images/77913911_rvZrG.png already exists, skipping
# ../images/77913911_JyGBV.png already exists, skipping
# Downloading https://i.sstatic.net/oVQHV.png to ../images/78090926_oVQHV.png
# Downloaded https://i.sstatic.net/oVQHV.png to ../images/78090926_oVQHV.png
# ../images/78090926_tYXeu.png already exists, skipping
# ../images/78090926_C4mVK.png already exists, skipping
# Downloading https://i.sstatic.net/yfBQt.png to ../images/78090926_yfBQt.png
# Downloaded https://i.sstatic.net/yfBQt.png to ../images/78090926_yfBQt.png
# Downloading https://i.sstatic.net/rFt48.png to ../images/78090926_rFt48.png
# Downloaded https://i.sstatic.net/rFt48.png to ../images/78090926_rFt48.png
# ../images/78641475_KgDI81Gy.png already exists, skipping
# ../images/77732819_i3f6q.png already exists, skipping
# ../images/77732819_pUErO.png already exists, skipping
# Downloading https://i.sstatic.net/UxXwj.png to ../images/77192526_UxXwj.png
# Downloaded https://i.sstatic.net/UxXwj.png to ../images/77192526_UxXwj.png
# ../images/77523276_6M4Da.png already exists, skipping
# ../images/77523276_kRrJq.png already exists, skipping
# Downloading https://i.sstatic.net/WgMU9.jpg to ../images/76858777_WgMU9.png
# Downloaded https://i.sstatic.net/WgMU9.jpg to ../images/76858777_WgMU9.png
# Downloading https://i.sstatic.net/GbXoR.png to ../images/78220472_GbXoR.png
# Downloaded https://i.sstatic.net/GbXoR.png to ../images/78220472_GbXoR.png
# Downloading https://i.sstatic.net/koyF4.png to ../images/78220472_koyF4.png
# Downloaded https://i.sstatic.net/koyF4.png to ../images/78220472_koyF4.png
# ../images/77342782_CFnJM.png already exists, skipping
# ../images/77342782_XEg2d.png already exists, skipping
# ../images/78589875_ycLdQs0w.png already exists, skipping
# ../images/78096627_kAieF.png already exists, skipping
# ../images/78096627_RnB1S.png already exists, skipping
# Downloading https://i.sstatic.net/J4rnt.png to ../images/77627190_J4rnt.png
# Downloaded https://i.sstatic.net/J4rnt.png to ../images/77627190_J4rnt.png
# Downloading https://i.sstatic.net/e2H7u.png to ../images/77273528_e2H7u.png
# Downloaded https://i.sstatic.net/e2H7u.png to ../images/77273528_e2H7u.png
# ../images/77273528_KbgCk.png already exists, skipping
# Downloading https://i.sstatic.net/LJNP1.png to ../images/77273528_LJNP1.png
# Downloaded https://i.sstatic.net/LJNP1.png to ../images/77273528_LJNP1.png
# ../images/78069185_WdhXf.png already exists, skipping
# Downloading https://i.sstatic.net/nfd3J.png to ../images/76897997_nfd3J.png
# Downloaded https://i.sstatic.net/nfd3J.png to ../images/76897997_nfd3J.png
# ../images/77942176_e3N3m.png already exists, skipping
# ../images/78582453_VCTExGat.png already exists, skipping
# ../images/78582453_ocDGzFA4.png already exists, skipping
# ../images/78582453_lR0i3W9F.png already exists, skipping
# ../images/78582453_DdTRJoR4.png already exists, skipping
# Downloading https://i.sstatic.net/5fn9V.png to ../images/77075262_5fn9V.png
# Downloaded https://i.sstatic.net/5fn9V.png to ../images/77075262_5fn9V.png
# Downloading https://i.sstatic.net/YB84O.png to ../images/76983200_YB84O.png
# Downloaded https://i.sstatic.net/YB84O.png to ../images/76983200_YB84O.png
# ../images/78571683_bnQNjyUr.png already exists, skipping
# ../images/77296947_ozZjL.png already exists, skipping
# Downloading https://i.sstatic.net/U5Evn.png to ../images/78023638_U5Evn.png
# Downloaded https://i.sstatic.net/U5Evn.png to ../images/78023638_U5Evn.png
# Downloading https://i.sstatic.net/AH5Ij.png to ../images/78052249_AH5Ij.png
# Downloaded https://i.sstatic.net/AH5Ij.png to ../images/78052249_AH5Ij.png
# ../images/77714605_fFaGp.png already exists, skipping
# ../images/77714605_zOoqr.png already exists, skipping
# Downloading https://i.sstatic.net/4hfzl6jL.png to ../images/78390784_4hfzl6jL.png
# Downloaded https://i.sstatic.net/4hfzl6jL.png to ../images/78390784_4hfzl6jL.png
# ../images/78390784_Lh3cGp4d.png already exists, skipping
# ../images/78295891_gfEDi.png already exists, skipping
# ../images/78295891_SkaJN.png already exists, skipping
# ../images/77238636_QMRhZ.png already exists, skipping
# Downloading https://i.sstatic.net/Umigz85E.png to ../images/78634000_Umigz85E.png
# Downloaded https://i.sstatic.net/Umigz85E.png to ../images/78634000_Umigz85E.png
# Downloading https://i.sstatic.net/kEHZAuHb.png to ../images/78634000_kEHZAuHb.png
# Downloaded https://i.sstatic.net/kEHZAuHb.png to ../images/78634000_kEHZAuHb.png
# Downloading https://i.sstatic.net/owuH8pA4.png to ../images/78634000_owuH8pA4.png
# Downloaded https://i.sstatic.net/owuH8pA4.png to ../images/78634000_owuH8pA4.png
# ../images/78634000_yr8wxx20.png already exists, skipping
# ../images/77553067_n8Ro8.png already exists, skipping
# ../images/77553067_bF63J.png already exists, skipping
# ../images/78008995_TBI8A.png already exists, skipping
# Downloading https://i.sstatic.net/lXWLz.png to ../images/76785438_lXWLz.png
# Downloaded https://i.sstatic.net/lXWLz.png to ../images/76785438_lXWLz.png
# Downloading https://i.sstatic.net/zN4ij.png to ../images/76785438_zN4ij.png
# Downloaded https://i.sstatic.net/zN4ij.png to ../images/76785438_zN4ij.png
# ../images/78340983_5767Y.png already exists, skipping
# Downloading https://i.sstatic.net/MfSyl.png to ../images/78340580_MfSyl.png
# Downloaded https://i.sstatic.net/MfSyl.png to ../images/78340580_MfSyl.png
# ../images/78340580_fK13f.png already exists, skipping
# Downloading https://i.sstatic.net/Hjhiv.png to ../images/78340580_Hjhiv.png
# Downloaded https://i.sstatic.net/Hjhiv.png to ../images/78340580_Hjhiv.png
# Downloading https://i.sstatic.net/UsSLP.png to ../images/78340580_UsSLP.png
# Downloaded https://i.sstatic.net/UsSLP.png to ../images/78340580_UsSLP.png
# ../images/77841632_GTCMe.png already exists, skipping
# ../images/77787226_i0KT8.png already exists, skipping
# ../images/76974101_9WFuX.png already exists, skipping
# ../images/78362701_LQYxH.png already exists, skipping
# ../images/78362701_sIWeb.png already exists, skipping
# Downloading https://i.sstatic.net/XaZSO.png to ../images/77699859_XaZSO.png
# Downloaded https://i.sstatic.net/XaZSO.png to ../images/77699859_XaZSO.png
# ../images/77118036_igHbv.png already exists, skipping
# Downloading https://i.sstatic.net/sZ34N.png to ../images/77655902_sZ34N.png
# Downloaded https://i.sstatic.net/sZ34N.png to ../images/77655902_sZ34N.png
# Downloading https://i.sstatic.net/DFDOo.png to ../images/77286371_DFDOo.png
# Downloaded https://i.sstatic.net/DFDOo.png to ../images/77286371_DFDOo.png
# ../images/78611316_fq4pBK6t.png already exists, skipping
# ../images/78465994_6Hj9rnMB.png already exists, skipping
# ../images/78059243_FbFDH.png already exists, skipping
# ../images/78303324_wRuDK.png already exists, skipping
# ../images/76978529_KnDYc.png already exists, skipping
# ../images/77212556_gsmxP.png already exists, skipping
# ../images/77212556_tgPfC.png already exists, skipping
# ../images/77212556_kZ31W.png already exists, skipping
# Downloading https://i.sstatic.net/4xVgW.png to ../images/77054851_4xVgW.png
# Downloaded https://i.sstatic.net/4xVgW.png to ../images/77054851_4xVgW.png
# ../images/77054851_aZxHt.png already exists, skipping
# ../images/78455275_jtCGeJeF.png already exists, skipping
# ../images/78455275_3G0vxTIl.png already exists, skipping
# Downloading https://i.sstatic.net/Psbjf.png to ../images/77640033_Psbjf.png
# Downloaded https://i.sstatic.net/Psbjf.png to ../images/77640033_Psbjf.png
# Downloading https://i.sstatic.net/2DAv2.png to ../images/77999553_2DAv2.png
# Downloaded https://i.sstatic.net/2DAv2.png to ../images/77999553_2DAv2.png
# Downloading https://i.sstatic.net/m89sJ.png to ../images/77999553_m89sJ.png
# Downloaded https://i.sstatic.net/m89sJ.png to ../images/77999553_m89sJ.png
# Downloading https://i.sstatic.net/aZVOu.png to ../images/77999553_aZVOu.png
# Downloaded https://i.sstatic.net/aZVOu.png to ../images/77999553_aZVOu.png
# ../images/77999553_M76tc.png already exists, skipping
# Downloading https://i.sstatic.net/vfbPk.png to ../images/77999553_vfbPk.png
# Downloaded https://i.sstatic.net/vfbPk.png to ../images/77999553_vfbPk.png
# ../images/78209313_5asE5.png already exists, skipping
# ../images/78456694_82yxji7T.png already exists, skipping
# Downloading https://i.sstatic.net/JtZ0b42C.png to ../images/78448927_JtZ0b42C.png
# Downloaded https://i.sstatic.net/JtZ0b42C.png to ../images/78448927_JtZ0b42C.png
# Downloading https://i.sstatic.net/5Z6ZA.png to ../images/77776608_5Z6ZA.png
# Downloaded https://i.sstatic.net/5Z6ZA.png to ../images/77776608_5Z6ZA.png
# Downloading https://i.sstatic.net/bhQrB.png to ../images/77988280_bhQrB.png
# Downloaded https://i.sstatic.net/bhQrB.png to ../images/77988280_bhQrB.png
# ../images/77988280_lUeca.png already exists, skipping
# Downloading https://i.sstatic.net/yKhmm.png to ../images/77988280_yKhmm.png
# Downloaded https://i.sstatic.net/yKhmm.png to ../images/77988280_yKhmm.png
# ../images/77701257_bAjTG.png already exists, skipping
# ../images/77701257_u3G5l.png already exists, skipping
# Downloading https://i.sstatic.net/PazZY.png to ../images/77789894_PazZY.png
# Downloaded https://i.sstatic.net/PazZY.png to ../images/77789894_PazZY.png
# Downloading https://i.sstatic.net/rmiMc.png to ../images/77789894_rmiMc.png
# Downloaded https://i.sstatic.net/rmiMc.png to ../images/77789894_rmiMc.png
# Downloading https://i.sstatic.net/lepmR.jpg to ../images/78095224_lepmR.png
# Downloaded https://i.sstatic.net/lepmR.jpg to ../images/78095224_lepmR.png
# Downloading https://i.sstatic.net/3AWmg.jpg to ../images/78095224_3AWmg.png
# Downloaded https://i.sstatic.net/3AWmg.jpg to ../images/78095224_3AWmg.png
# Downloading https://i.sstatic.net/pwIIT.png to ../images/78184347_pwIIT.png
# Downloaded https://i.sstatic.net/pwIIT.png to ../images/78184347_pwIIT.png
# Downloading https://i.sstatic.net/aEjzY.png to ../images/78184347_aEjzY.png
# Downloaded https://i.sstatic.net/aEjzY.png to ../images/78184347_aEjzY.png
# ../images/78184347_x0bKx.png already exists, skipping
# Downloading https://i.sstatic.net/iJRmU.png to ../images/78159686_iJRmU.png
# Downloaded https://i.sstatic.net/iJRmU.png to ../images/78159686_iJRmU.png
# ../images/78159686_cFRIr.png already exists, skipping
# Downloading https://i.sstatic.net/NdX5Z.png to ../images/78159686_NdX5Z.png
# Downloaded https://i.sstatic.net/NdX5Z.png to ../images/78159686_NdX5Z.png
# ../images/77020908_JYtXg.png already exists, skipping
# ../images/77587827_wrCdm.png already exists, skipping
# ../images/77587827_iSqaM.png already exists, skipping
# ../images/77587827_FJsb3.png already exists, skipping
# Downloading https://i.sstatic.net/97wAW.png to ../images/77428679_97wAW.png
# Downloaded https://i.sstatic.net/97wAW.png to ../images/77428679_97wAW.png
# Downloading https://i.sstatic.net/fIk21c6t.png to ../images/78669479_fIk21c6t.png
# Downloaded https://i.sstatic.net/fIk21c6t.png to ../images/78669479_fIk21c6t.png
# ../images/77597057_pxB76.png already exists, skipping
# Downloading https://i.sstatic.net/kWL4b.png to ../images/77152383_kWL4b.png
# Downloaded https://i.sstatic.net/kWL4b.png to ../images/77152383_kWL4b.png
# ../images/78477680_wivslWuY.png already exists, skipping
# ../images/77932409_Cyg3w.png already exists, skipping
# ../images/77052620_cNXmO.png already exists, skipping
# ../images/77457552_HL6dX.png already exists, skipping
# ../images/77457552_6Noto.png already exists, skipping
# ../images/77457552_CzMBl.png already exists, skipping
# ../images/77750508_m8F9y.png already exists, skipping
# Downloading https://i.sstatic.net/Qn8w5.jpg to ../images/77865041_Qn8w5.png
# Downloaded https://i.sstatic.net/Qn8w5.jpg to ../images/77865041_Qn8w5.png
# ../images/77865041_BUnwq.png already exists, skipping
# ../images/77541171_9PsGL.png already exists, skipping
# ../images/78565213_DaQcW8U4.png already exists, skipping
# ../images/78565213_mLJPlxxD.png already exists, skipping
# Downloading https://i.sstatic.net/b1LRA.png to ../images/78132875_b1LRA.png
# Downloaded https://i.sstatic.net/b1LRA.png to ../images/78132875_b1LRA.png
# Downloading https://i.sstatic.net/KRJvU.png to ../images/78132875_KRJvU.png
# Downloaded https://i.sstatic.net/KRJvU.png to ../images/78132875_KRJvU.png
# ../images/77674418_rk3Nb.png already exists, skipping
# ../images/77674418_FbKdd.png already exists, skipping
# ../images/78293178_TMFFhusJ.png already exists, skipping
# Downloading https://i.sstatic.net/JVKkQa2C.png to ../images/78431858_JVKkQa2C.png
# Downloaded https://i.sstatic.net/JVKkQa2C.png to ../images/78431858_JVKkQa2C.png
# ../images/78158180_1luNq.png already exists, skipping
# ../images/78158180_o604R.png already exists, skipping
# ../images/78158180_qgqH2.png already exists, skipping
# ../images/77732288_3SfTe.png already exists, skipping
# Downloading https://i.sstatic.net/SKAlq.png to ../images/76960135_SKAlq.png
# Downloaded https://i.sstatic.net/SKAlq.png to ../images/76960135_SKAlq.png
# Downloading https://i.sstatic.net/Ymoao.png to ../images/76960135_Ymoao.png
# Downloaded https://i.sstatic.net/Ymoao.png to ../images/76960135_Ymoao.png
# Downloading https://i.sstatic.net/zru3N.png to ../images/76960135_zru3N.png
# Downloaded https://i.sstatic.net/zru3N.png to ../images/76960135_zru3N.png
# Downloading https://i.sstatic.net/BYv2T.png to ../images/76960135_BYv2T.png
# Downloaded https://i.sstatic.net/BYv2T.png to ../images/76960135_BYv2T.png
# Downloading https://i.sstatic.net/oewIe.png to ../images/76960135_oewIe.png
# Downloaded https://i.sstatic.net/oewIe.png to ../images/76960135_oewIe.png
# ../images/76931585_hzA2e.png already exists, skipping
# ../images/77730048_AyGxE.png already exists, skipping
# ../images/78476485_AECnQa8J.png already exists, skipping
# Downloading https://i.sstatic.net/LhJAg.png to ../images/77228401_LhJAg.png
# Downloaded https://i.sstatic.net/LhJAg.png to ../images/77228401_LhJAg.png
# ../images/77539376_vJOfB.png already exists, skipping
# ../images/77539376_XogoW.png already exists, skipping
# ../images/77539376_VcBHL.png already exists, skipping
# ../images/78277078_nwaht.png already exists, skipping
# Downloading https://i.sstatic.net/PLOaN.png to ../images/78081612_PLOaN.png
# Downloaded https://i.sstatic.net/PLOaN.png to ../images/78081612_PLOaN.png
# Downloading https://i.sstatic.net/8saOQ.png to ../images/78081612_8saOQ.png
# Downloaded https://i.sstatic.net/8saOQ.png to ../images/78081612_8saOQ.png
# ../images/77667293_sBrHQ.png already exists, skipping
# Downloading https://i.sstatic.net/LDySl.png to ../images/77667293_LDySl.png
# Downloaded https://i.sstatic.net/LDySl.png to ../images/77667293_LDySl.png
# ../images/78649212_tlC0qsyf.png already exists, skipping
# ../images/78674751_9QE26tpK.png already exists, skipping
# ../images/76842683_fWnzB.png already exists, skipping
